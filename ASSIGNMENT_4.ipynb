# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitkumar2003/AI_and_Data-Skills.Hub/blob/main/ASSIGNMENT_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #//**Practice and Data Manipulation**//

# %%
10.5
# Out:
# 10.5

# %%
type('ybi')
# Out:
# str

# %%
x = 9

# %%
age = 29

# %%
2 == 3
# Out:
# False

# %%
2<3
# Out:
# True

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Admission%20Chance.csv')

# %%
df
# Out:
#      Serial No  GRE Score  TOEFL Score  University Rating   SOP  LOR   CGPA  \
# 0            1        337          118                  4   4.5   4.5  9.65
# 1            2        324          107                  4   4.0   4.5  8.87
# 2            3        316          104                  3   3.0   3.5  8.00
# 3            4        322          110                  3   3.5   2.5  8.67
# 4            5        314          103                  2   2.0   3.0  8.21
# ..         ...        ...          ...                ...   ...   ...   ...
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df1 = pd.read_excel('https://github.com/YBIFoundation/Dataset/raw/main/Gapminder_IRIS.xlsx',sheet_name=None)

# %%
df1
# Out:
# {'Sheet1':      population  fertility   HIV        CO2  BMI_male    GDP  BMI_female  \
#  0      34811059       2.73   0.1   3.328945  24.59620  12314    129.9049
#  1      19842251       6.43   2.0   1.474353  22.25083   7103    130.1247
#  2      40381860       2.24   0.5   4.785170  27.50170  14646    118.8915
#  3       2975029       1.40   0.1   1.804106  25.35542   7383    132.8108
#  4      21370348       1.96   0.1  18.016313  27.56373  41312    117.3755
#  ..          ...        ...   ...        ...       ...    ...         ...
#  134     3350832       2.11   0.5   2.489764  26.39123  15317    124.2604
#  135    26952719       2.46   0.1   4.476669  25.32054   3733    124.3462
#  136    86589342       1.86   0.4   1.479347  20.91630   4085    121.9367
#  137    13114579       5.88  13.6   0.148982  20.68321   3039    132.4493
#  138    13495462       3.85  15.1   0.654323  22.02660   1286    131.9745
#
#       life  child_mortality                      Region
# ...

# %% [markdown]
# #**//Data Manipulation with Pandas//**

# %%
# install pandas
# !pip install pandas

# %%
# version
pd.__version__
# Out:
# '1.5.3'

# %%
# latest version
# !pip install -U pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 16.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.1 which is incompatible.
# ...

# %%
# different version
pd.show_versions()
# Out:
# /usr/local/lib/python3.10/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit           : 2e218d10984e9919f0296931d92ea851c6a6faf5
# python           : 3.10.12.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.15.120+
# Version          : #1 SMP Wed Aug 30 11:19:59 UTC 2023
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : en_US.UTF-8
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.5.3
# numpy            : 1.23.5
# pytz             : 2023.3.post1
# dateutil         : 2.8.2
# setuptools       : 67.7.2
# pip              : 23.1.2
# Cython           : 3.0.2
# pytest           : 7.4.1
# hypothesis       : None
# sphinx           : 5.0.2
# blosc            : None
# feather          : None
# xlsxwriter       : None
# ...

# %%
# import library
import pandas as pd

# %%
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 1, 'Allen, Miss. Elisabeth Walton', ..., '2', nan,
#         'St Louis, MO'],
#        [1, 1, 'Allison, Master. Hudson Trevor', ..., '11', nan,
#         'Montreal, PQ / Chesterville, ON'],
#        [1, 0, 'Allison, Miss. Helen Loraine', ..., nan, nan,
#         'Montreal, PQ / Chesterville, ON'],
#        ...,
#        [3, 0, 'Zakarian, Mr. Mapriededer', ..., nan, 304.0, nan],
#        [3, 0, 'Zakarian, Mr. Ortin', ..., nan, nan, nan],
#        [3, 0, 'Zimmerman, Mr. Leo', ..., nan, nan, nan]], dtype=object)

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# select a single column
s1 = df['pclass']

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.shape
# Out:
# (1309,)

# %%
# select a single column
d1 = df[['pclass']]

# %%
type(d1)
# Out:
# pandas.core.frame.DataFrame

# %%
d1.shape
# Out:
# (1309, 1)

# %%
df[['pclass', 'name', 'fare' , 'cabin'  ]]
# Out:
#       pclass                                             name      fare  \
# 0          1                    Allen, Miss. Elisabeth Walton  211.3375
# 1          1                   Allison, Master. Hudson Trevor  151.5500
# 2          1                     Allison, Miss. Helen Loraine  151.5500
# 3          1             Allison, Mr. Hudson Joshua Creighton  151.5500
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500
# ...      ...                                              ...       ...
# 1304       3                             Zabour, Miss. Hileni   14.4542
# 1305       3                            Zabour, Miss. Thamine   14.4542
# 1306       3                        Zakarian, Mr. Mapriededer    7.2250
# 1307       3                              Zakarian, Mr. Ortin    7.2250
# 1308       3                               Zimmerman, Mr. Leo    7.8750
#
#         cabin
# 0          B5
# 1     C22 C26
# 2     C22 C26
# 3     C22 C26
# 4     C22 C26
# ...

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.loc[   1:10:2     ,   ['fare','name' ]         ]
# Out:
#        fare                                  name
# 1  151.5500        Allison, Master. Hudson Trevor
# 3  151.5500  Allison, Mr. Hudson Joshua Creighton
# 5   26.5500                   Anderson, Mr. Harry
# 7    0.0000                Andrews, Mr. Thomas Jr
# 9   49.5042               Artagaveytia, Mr. Ramon

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df['age']<18
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
df.loc[df['age']<18,['name','age']]
# Out:
#                                          name    age
# 1              Allison, Master. Hudson Trevor   0.92
# 2                Allison, Miss. Helen Loraine   2.00
# 53                     Carrau, Mr. Jose Pedro  17.00
# 54        Carter, Master. William Thornton II  11.00
# 55                  Carter, Miss. Lucile Polk  14.00
# ...                                       ...    ...
# 1265                Van Impe, Miss. Catharina  10.00
# 1275          Vander Planke, Mr. Leo Edmondus  16.00
# 1279     Vestrom, Miss. Hulda Amanda Adolfina  14.00
# 1300  Yasbeck, Mrs. Antoni (Selini Alexander)  15.00
# 1304                     Zabour, Miss. Hileni  14.50
#
# [154 rows x 2 columns]

# %%
df['sex']=='male'
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306     True
# 1307     True
# 1308     True
# Name: sex, Length: 1309, dtype: bool

# %%
df.loc[(df['sex']=='male'),2:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-89c0db3ae618> in <cell line: 1>()
# ----> 1 df.loc[(df['sex']=='male'),2:3]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065         raise IndexingError("not applicable")
#    1066
# -> 1067     @final
#    1068     def _getitem_nested_tuple(self, tup: tuple):
#    1069         # we have a nested tuple so have at least 1 multi-index level
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254         Parameters
#    1255         ----------
# -> 1256         tup : tuple
#    1257             Tuple of indexers, one per axis.
#    1258
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     922                 i = tup.index(Ellipsis)
# ...

# %%
(df['sex']=='male') & (df['age']>60)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Length: 1309, dtype: bool

# %%
df.loc[  (df['sex']=='male') & (df['age']>70)     , 'pclass': 'age'  ]
# Out:
#       pclass  survived                                  name   sex   age
# 9          1         0               Artagaveytia, Mr. Ramon  male  71.0
# 14         1         1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 135        1         0             Goldschmidt, Mr. George B  male  71.0
# 727        3         0                  Connors, Mr. Patrick  male  70.5
# 1235       3         0                   Svensson, Mr. Johan  male  74.0

# %%
df.query( ' age>70 and fare>10  '  )
# Out:
#      pclass  survived                                               name  \
# 9         1         0                            Artagaveytia, Mr. Ramon
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
# 61        1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 135       1         0                          Goldschmidt, Mr. George B
#
#         sex   age  sibsp  parch    ticket     fare cabin embarked boat  body  \
# 9      male  71.0      0      0  PC 17609  49.5042   NaN        C  NaN  22.0
# 14     male  80.0      0      0     27042  30.0000   A23        S    B   NaN
# 61   female  76.0      1      0     19877  78.8500   C46        S    6   NaN
# 135    male  71.0      0      0  PC 17754  34.6542    A5        C  NaN   NaN
#
#                    home.dest
# 9        Montevideo, Uruguay
# 14             Hessle, Yorks
# 61   Little Onn Hall, Staffs
# 135             New York, NY

# %%
df.query( "age>70 and sex== 'male' and fare<10"  )
# Out:
#       pclass  survived                  name   sex   age  sibsp  parch  \
# 727        3         0  Connors, Mr. Patrick  male  70.5      0      0
# 1235       3         0   Svensson, Mr. Johan  male  74.0      0      0
#
#       ticket   fare cabin embarked boat   body home.dest
# 727   370369  7.750   NaN        Q  NaN  171.0       NaN
# 1235  347060  7.775   NaN        S  NaN    NaN       NaN

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.loc[1:3,'name':'sex']
# Out:
#                                    name     sex
# 1        Allison, Master. Hudson Trevor    male
# 2          Allison, Miss. Helen Loraine  female
# 3  Allison, Mr. Hudson Joshua Creighton    male

# %%
df.iloc[1:3,2:3]
# Out:
#                              name
# 1  Allison, Master. Hudson Trevor
# 2    Allison, Miss. Helen Loraine

# %%
df.iloc[1:3,[3,2]]
# Out:
#       sex                            name
# 1    male  Allison, Master. Hudson Trevor
# 2  female    Allison, Miss. Helen Loraine
